# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\tarun\\OneDrive'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\tarun'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    data_path: Path
    model_path: Path
    tokenizer_path: Path
    metric_file_name: Path

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:
        config = self.config.model_evaluation

        create_directories([config.root_dir])

        model_evaluation_config = ModelEvaluationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
            model_path = config.model_path,
            tokenizer_path = config.tokenizer_path,
            metric_file_name = config.metric_file_name
           
        )

        return model_evaluation_config

# %%
# %pip install evaluate
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datasets import load_dataset, load_from_disk
from evaluate import load as load_metric
import torch
import pandas as pd
from tqdm import tqdm
# Out:
# Requirement already satisfied: evaluate in c:\users\tarun\miniconda3_new\lib\site-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\tarun\miniconda3_new\lib\site-packages (from evaluate) (4.4.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from evaluate) (2.3.2)
# Requirement already satisfied: dill in c:\users\tarun\miniconda3_new\lib\site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in c:\users\tarun\miniconda3_new\lib\site-packages (from evaluate) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\tarun\miniconda3_new\lib\site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\tarun\miniconda3_new\lib\site-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.7.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from evaluate) (0.34.4)
# Requirement already satisfied: packaging in c:\users\tarun\appdata\roaming\python\python313\site-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in c:\users\tarun\appdata\roaming\python\python313\site-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\tarun\miniconda3_new\lib\site-packages (from datasets>=2.0.0->evaluate) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.15)
# Requirement already satisfied: anyio in c:\users\tarun\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.10.0)
# Requirement already satisfied: certifi in c:\users\tarun\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\tarun\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: idna in c:\users\tarun\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->evaluate) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: colorama in c:\users\tarun\appdata\roaming\python\python313\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tarun\miniconda3_new\lib\site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tarun\miniconda3_new\lib\site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tarun\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig):
        self.config = config


    
    def generate_batch_sized_chunks(self,list_of_elements, batch_size):
        """split the dataset into smaller batches that we can process simultaneously
        Yield successive batch-sized chunks from list_of_elements."""
        for i in range(0, len(list_of_elements), batch_size):
            yield list_of_elements[i : i + batch_size]

    
    def calculate_metric_on_test_ds(self,dataset, metric, model, tokenizer, 
                               batch_size=16, device="cuda" if torch.cuda.is_available() else "cpu", 
                               column_text="article", 
                               column_summary="highlights"):
        article_batches = list(self.generate_batch_sized_chunks(dataset[column_text], batch_size))
        target_batches = list(self.generate_batch_sized_chunks(dataset[column_summary], batch_size))

        for article_batch, target_batch in tqdm(
            zip(article_batches, target_batches), total=len(article_batches)):
            
            inputs = tokenizer(article_batch, max_length=1024,  truncation=True, 
                            padding="max_length", return_tensors="pt")
            
            summaries = model.generate(input_ids=inputs["input_ids"].to(device),
                            attention_mask=inputs["attention_mask"].to(device), 
                            length_penalty=0.8, num_beams=8, max_length=128)
            ''' parameter for length penalty ensures that the model does not generate sequences that are too long. '''
            
            # Finally, we decode the generated texts, 
            # replace the  token, and add the decoded texts with the references to the metric.
            decoded_summaries = [tokenizer.decode(s, skip_special_tokens=True, 
                                    clean_up_tokenization_spaces=True) 
                for s in summaries]      
            
            decoded_summaries = [d.replace("", " ") for d in decoded_summaries]
            
            
            metric.add_batch(predictions=decoded_summaries, references=target_batch)
            
        #  Finally compute and return the ROUGE scores.
        score = metric.compute()
        return score


    def evaluate(self):
        device = "cuda" if torch.cuda.is_available() else "cpu"
        tokenizer = AutoTokenizer.from_pretrained(self.config.tokenizer_path)
        model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_path).to(device)
       
        #loading data 
        dataset_samsum_pt = load_from_disk(self.config.data_path)


        rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
  
        rouge_metric = load_metric('rouge')

        score = self.calculate_metric_on_test_ds(
        dataset_samsum_pt['test'][0:10], rouge_metric, model_pegasus, tokenizer, batch_size = 2, column_text = 'dialogue', column_summary= 'summary'
            )

        rouge_dict = dict((rn, score[rn].mid.fmeasure ) for rn in rouge_names )

        df = pd.DataFrame(rouge_dict, index = ['pegasus'] )
        df.to_csv(self.config.metric_file_name, index=False)

# %%
try:
    # Check if config file exists, if not navigate to project root
    if not os.path.exists(CONFIG_FILE_PATH):
        # Navigate to the project root directory
        os.chdir('../')
    
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation_config()
    model_evaluation = ModelEvaluation(config=model_evaluation_config)
    model_evaluation.evaluate()
except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 12
#      10     model_evaluation.evaluate()
#      11 except Exception as e:
# ---> 12     raise e
#
# Cell In[39], line 7
#       3 if not os.path.exists(CONFIG_FILE_PATH):
#       4     # Navigate to the project root directory
#       5     os.chdir('../')
# ----> 7 config = ConfigurationManager()
#       8 model_evaluation_config = config.get_model_evaluation_config()
#       9 model_evaluation = ModelEvaluation(config=model_evaluation_config)
#
# Cell In[36], line 7, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       2 def __init__(
#       3     self,
#       4     config_filepath = CONFIG_FILE_PATH,
#       5     params_filepath = PARAMS_FILE_PATH):
# ----> 7     self.config = read_yaml(config_filepath)
#       8     self.params = read_yaml(params_filepath)
#      10     create_directories([self.config.artifacts_root])
#
# File ~\OneDrive\Pictures\Desktop\MINI LLM Summarizier\Text-Summarization-NLP-Project\src\textSummarizer\utils\common.py:32, in read_yaml(path_to_yaml)
#      30     raise ValueError("yaml file is empty")
#      31 except Exception as e:
# ---> 32     raise e
#
# File ~\OneDrive\Pictures\Desktop\MINI LLM Summarizier\Text-Summarization-NLP-Project\src\textSummarizer\utils\common.py:25, in read_yaml(path_to_yaml)
#      12 """reads yaml file and returns
#      13
#      14 Args:
#    (...)     22     ConfigBox: ConfigBox type
#      23 """
#      24 try:
# ---> 25     with open(path_to_yaml) as yaml_file:
#      26         content = yaml.safe_load(yaml_file)
#      27         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'
